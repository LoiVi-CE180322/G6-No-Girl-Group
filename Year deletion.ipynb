# %%
import pandas as pd
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')

# Load the dataset from Google Drive
file_path = '/content/drive/MyDrive/movie.csv'
df = pd.read_csv(file_path)

# Remove the year from the 'title' column
df['title'] = df['title'].str.replace(r'\s\(\d{4}\)', '', regex=True)

# Display the first few rows to verify the changes
df.head()

# Save the modified dataset to a new CSV file
output_path = '/content/drive/MyDrive/movie_no_year.csv'
df.to_csv(output_path, index=False)

print(f"Modified file saved at: {output_path}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Modified file saved at: /content/drive/MyDrive/movie_no_year.csv
