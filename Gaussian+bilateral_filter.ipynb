# %%
# !pip install opencv-python-headless matplotlib
# !pip install opencv-python-headless
import cv2
import matplotlib.pyplot as plt

# %%
img_path = '/content/sample_data/surprised_car.png'
img = cv2.imread(img_path)
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
blurred_img = cv2.GaussianBlur(img_rgb, (75, 75), 0)

plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
plt.imshow(img_rgb)
plt.title('Original Image')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(blurred_img)
plt.title('Even More Blurred Image (75x75 Kernel)')
plt.axis('off')

plt.show()

# %%
img_path = '/content/sample_data/surprised_car.png'
img = cv2.imread(img_path)

img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
filtered_img = cv2.bilateralFilter(img, d=9, sigmaColor=100000, sigmaSpace=100000)

filtered_img_rgb = cv2.cvtColor(filtered_img, cv2.COLOR_BGR2RGB)

plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.imshow(img_rgb)
plt.title('Original Image')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(filtered_img_rgb)
plt.title('Bilateral Filtered Image')
plt.axis('off')

plt.show()

# %%
from google.colab import drive
drive.mount('/content/drive')
