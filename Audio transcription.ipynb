# %%
# Step 1: Install the required libraries
# !pip install vosk pydub soundfile

# Step 2: Download a small Vosk model (this might take some time)
# !wget https://alphacephei.com/vosk/models/vosk-model-small-en-us-0.15.zip
# !unzip -o vosk-model-small-en-us-0.15.zip  # The -o flag overwrites without confirmation

# Step 3: Mount Google Drive to access the audio file
from google.colab import drive
drive.mount('/content/drive')

# Step 4: Convert the audio file to mono PCM 16kHz using pydub
from pydub import AudioSegment

# Path to your original .wav file in Google Drive (replace with your path)
original_audio_file_path = '/content/drive/MyDrive/extracted_audio.wav





'  # Update this path

# Load the original audio
audio = AudioSegment.from_wav(original_audio_file_path)

# Convert to mono, PCM, 16kHz
audio = audio.set_channels(1)  # Mono
audio = audio.set_frame_rate(16000)  # 16kHz
converted_audio_file_path = '/content/converted_audio.wav'
audio.export(converted_audio_file_path, format='wav')

# Step 5: Transcribe the audio using Vosk
import os
import wave
import json
from vosk import Model, KaldiRecognizer

# Load the Vosk model
model = Model("vosk-model-small-en-us-0.15")

# Open the converted .wav file
wf = wave.open(converted_audio_file_path, "rb")

# Check if the audio file is in the correct format (it should be, after conversion)
if wf.getnchannels() != 1 or wf.getsampwidth() != 2 or wf.getframerate() > 16000:
    print("Audio file must be WAV format mono PCM with 16kHz or lower.")
else:
    # Initialize recognizer
    rec = KaldiRecognizer(model, wf.getframerate())

    # Transcribe the audio
    transcription = ""
    while True:
        data = wf.readframes(4000)
        if len(data) == 0:
            break
        if rec.AcceptWaveform(data):
            result = rec.Result()
            transcription_json = json.loads(result)
            transcription += transcription_json.get("text", "") + " "

    # Final result
    transcription += json.loads(rec.FinalResult()).get("text", "")
    print("Transcription: ", transcription)
# Out:
# Requirement already satisfied: vosk in /usr/local/lib/python3.10/dist-packages (0.3.45)
# Requirement already satisfied: pydub in /usr/local/lib/python3.10/dist-packages (0.25.1)
# Requirement already satisfied: soundfile in /usr/local/lib/python3.10/dist-packages (0.12.1)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.10/dist-packages (from vosk) (1.17.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from vosk) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from vosk) (4.66.5)
# Requirement already satisfied: srt in /usr/local/lib/python3.10/dist-packages (from vosk) (3.5.3)
# Requirement already satisfied: websockets in /usr/local/lib/python3.10/dist-packages (from vosk) (13.0.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0->vosk) (2.22)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->vosk) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->vosk) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->vosk) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->vosk) (2024.8.30)
# --2024-09-06 06:09:18--  https://alphacephei.com/vosk/models/vosk-model-small-en-us-0.15.zip
# Resolving alphacephei.com (alphacephei.com)... 188.40.21.16, 2a01:4f8:13a:279f::2
# Connecting to alphacephei.com (alphacephei.com)|188.40.21.16|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 41205931 (39M) [application/zip]
# Saving to: ‘vosk-model-small-en-us-0.15.zip.2’
#
# vosk-model-small-en 100%[===================>]  39.30M  18.7MB/s    in 2.1s
#
# 2024-09-06 06:09:21 (18.7 MB/s) - ‘vosk-model-small-en-us-0.15.zip.2’ saved [41205931/41205931]
#
# Archive:  vosk-model-small-en-us-0.15.zip
#   inflating: vosk-model-small-en-us-0.15/am/final.mdl
#   inflating: vosk-model-small-en-us-0.15/graph/disambig_tid.int
#   inflating: vosk-model-small-en-us-0.15/graph/HCLr.fst
#   inflating: vosk-model-small-en-us-0.15/graph/Gr.fst
#   inflating: vosk-model-small-en-us-0.15/graph/phones/word_boundary.int
#   inflating: vosk-model-small-en-us-0.15/conf/model.conf
#   inflating: vosk-model-small-en-us-0.15/conf/mfcc.conf
#   inflating: vosk-model-small-en-us-0.15/ivector/splice.conf
#   inflating: vosk-model-small-en-us-0.15/ivector/final.dubm
#   inflating: vosk-model-small-en-us-0.15/ivector/global_cmvn.stats
#   inflating: vosk-model-small-en-us-0.15/ivector/final.ie
#   inflating: vosk-model-small-en-us-0.15/ivector/online_cmvn.conf
#   inflating: vosk-model-small-en-us-0.15/ivector/final.mat
#   inflating: vosk-model-small-en-us-0.15/README
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Transcription:  hey michael thanks for coming up to mundo lingo last night it was really great to see you and have time to talk in such great detail about many things i spoke with a friend of mine in america this morning and he made a suggestion to me that i wanna share with you in a moment but i wanna and by you first to consider this idea in this in in the context of what we're already talking about which i'm i'm thinking specifically about your feedback on the you tube videos us your desire to or or your incur judgment for me to consider having a tick tock channel and so i think maybe these three things could be combined so first of all what if we mitigate the shortcomings of the videos that i made before for facebook live that i'm currently uploading to the new you tube channel by actually removing the video and just using the audio and then the question becomes whoa what visual do we used to go with the audio of those videos and that sounds like where we got to when we were talking about the possibility of tick tock it's not a priority for me but if we're gonna do it at all at any time in the future i'm not really interested in being visual like being a representative for this i want people just to focus on the word so you said sure tick tock channels could be face less and and just have words and sounds so what what if we started thinking differently about the videos that were preparing for face book and then that work might be suitable for them the second platform of tick tock or at least help us get more familiar with like you know what what's the best way to narrow down the message in to sort of a digestible size that could go on you tube or tick tock so you may be thinking about content that goes to both or maybe just the learning from one in a way that will help us create for the other and then here comes my friends idea he said if the idea really is to strip away everything else and just basically have words in the most isolated smallest unit size like i had and shirt and the stuff that will be on zazzle why not look to get some of these some of these sentences listed on quotation web sites and i really like this idea you know quotes about simplicity like i've got some really unique ones and quotes about infinity and quotes about laughter like i've got unique quotes about all of these things so and i don't know which quote web sites would be easier to get onto but there's a bunch of i'm and i don't know the process by which they integrate new quotes but that would be for me a great project to have you work on you know doing research and and then ultimately making submissions that could get the ideas out there in another free platform the by zazzle you know people are looking they're finding my ideas without having to pay to see them so quote website you know free access to these ideas exactly when you're looking for them and then you find speaker a writer whose sharing ideas that are making sense to you are resonating with you are making you curious about more and then that leads people to find done than where i really want to be found which is either like on the main let it be simple website or on my amazon page buying my books or on zazzle so this this feels like a good marketing idea getting it included on quote website so what do you think that what do you think about the you to tick tock kind of overlap at least some when you think about stripping out the visuals of me sitting in my kitchen making making those videos last year
