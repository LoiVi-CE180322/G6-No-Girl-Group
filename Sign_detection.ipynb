# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="5zDxkPCtp3MsrZnHtDo0")
project = rf.workspace("mjrob").project("road-signs-ohan1")
version = project.version(2)
dataset = version.download("yolov8")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.3/80.3 kB 3.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 4.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 2.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: idna
#     Found existing installation: idna 3.8
#     Uninstalling idna-3.8:
#       Successfully uninstalled idna-3.8
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# [WARNING] we noticed you are downloading a `yolov8` datasets but you don't have `ultralytics` installed. Roboflow `.deploy` supports only models trained with `ultralytics==8.0.196`, to intall it `pip install ultralytics==8.0.196`.
# ...
# Extracting Dataset Version Zip to Road-signs-2 in yolov8:: 100%|██████████| 47532/47532 [00:08<00:00, 5637.56it/s]

# %%
# !git clone https://github.com/THU-MIG/yolov10.git
# Out:
# Cloning into 'yolov10'...
# remote: Enumerating objects: 20329, done.
# remote: Counting objects: 100% (2443/2443), done.
# remote: Compressing objects: 100% (247/247), done.
# remote: Total 20329 (delta 2315), reused 2196 (delta 2196), pack-reused 17886 (from 1)
# Receiving objects: 100% (20329/20329), 11.14 MiB | 7.28 MiB/s, done.
# Resolving deltas: 100% (14335/14335), done.

# %%
# !nvidia-smi
# Out:
# Wed Sep 18 16:28:22 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   45C    P8              12W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
# !pip install ultralytics
from ultralytics import YOLO

model = YOLO('/content/Road-signs-2/yolov8m.pt')

model.train(data="/content/Road-signs-2/data.yaml", epochs = 5, batch = 4, imgsz = 640)
# Out:
# ...
# Ultralytics YOLOv8.2.96 🚀 Python-3.10.12 torch-2.4.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...
