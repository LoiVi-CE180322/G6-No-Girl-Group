# %%
# Importing necessary libraries
import numpy as np
import pandas as fh
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

# Sample data with more variance
data = {
    'length': [150.0, 168.8, 180.0, 200.0, 250.0, 300.0, 350.0],
    'width': [50.0, 60.0, 64.1, 65.5, 70.0, 80.0, 90.0],
    'height': [40.0, 48.8, 50.0, 52.4, 55.0, 60.0, 65.0]
}

# Creating a DataFrame
df = pd.DataFrame(data)

# Simple Feature Scaling
df_simple_scaled = df.copy()
df_simple_scaled['length'] = df['length'] / df['length'].max()
df_simple_scaled['width'] = df['width'] / df['width'].max()
df_simple_scaled['height'] = df['height'] / df['height'].max()

# Min-Max Scaling using sklearn's MinMaxScaler
scaler = MinMaxScaler()
df_minmax_scaled = pd.DataFrame(scaler.fit_transform(df), columns=df.columns)

# Plotting the original and scaled data for comparison

# Plot the original data
plt.figure(figsize=(12, 8))

plt.subplot(3, 1, 1)
plt.title('Original Data')
plt.plot(df, marker='o')
plt.legend(df.columns)
plt.grid(True)

# Plot the Simple Feature Scaled data
plt.subplot(3, 1, 2)
plt.title('Simple Feature Scaled Data')
plt.plot(df_simple_scaled, marker='o')
plt.legend(df_simple_scaled.columns)
plt.grid(True)

# Plot the Min-Max Scaled data
plt.subplot(3, 1, 3)
plt.title('Min-Max Scaled Data')
plt.plot(df_minmax_scaled, marker='o')
plt.legend(df_minmax_scaled.columns)
plt.grid(True)

plt.tight_layout()
plt.show()

# Printing the data to compare the values
print("Original Data:\n", df)
print("\nSimple Feature Scaled Data:\n", df_simple_scaled)
print("\nMin-Max Scaled Data:\n", df_minmax_scaled)
# Out:
# Original Data:
#     length  width  height
# 0   150.0   50.0    40.0
# 1   168.8   60.0    48.8
# 2   180.0   64.1    50.0
# 3   200.0   65.5    52.4
# 4   250.0   70.0    55.0
# 5   300.0   80.0    60.0
# 6   350.0   90.0    65.0
#
# Simple Feature Scaled Data:
#       length     width    height
# 0  0.428571  0.555556  0.615385
# 1  0.482286  0.666667  0.750769
# 2  0.514286  0.712222  0.769231
# 3  0.571429  0.727778  0.806154
# 4  0.714286  0.777778  0.846154
# 5  0.857143  0.888889  0.923077
# 6  1.000000  1.000000  1.000000
#
# Min-Max Scaled Data:
#     length   width  height
# 0   0.000  0.0000   0.000
# 1   0.094  0.2500   0.352
# 2   0.150  0.3525   0.400
# 3   0.250  0.3875   0.496
# 4   0.500  0.5000   0.600
# 5   0.750  0.7500   0.800
# 6   1.000  1.0000   1.000
